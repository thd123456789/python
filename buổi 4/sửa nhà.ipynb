# %%
import turtle
pen = turtle.Turtle()
a=90
turtle.bgcolor("cyan")
pen.speed(5)
pen.penup()
pen.backward(300)
pen.pendown()
pen.fillcolor("yellow")
pen.begin_fill()
pen.forward(50)
pen.right(a)
pen.forward(80)
pen.right(a)
pen.forward(50)
pen.right(a)
pen.forward(80)
pen.end_fill()
#mặt 2
pen.fillcolor("brown")
pen.begin_fill()
pen.right(30)
pen.forward(50)
pen.right(120)
pen.forward(50)
pen.right(120)
pen.forward(50)
pen.right(120)
pen.forward(50)
pen.right(120)
pen.forward(50)
pen.left(70)
pen.forward(150)
pen.left(110)
pen.forward(50)
pen.left(70)
pen.forward(150)
pen.end_fill()
#mặt 2.5
pen.penup()
pen.left(50)
pen.forward(50)
pen.left(30)
pen.forward(80)
pen.left(a)
pen.forward(50)
pen.pendown()
pen.fillcolor("yellow")
pen.begin_fill()
pen.left(10)
pen.forward(150)
pen.left(80)
pen.forward(80)
pen.left(100)
pen.forward(150)
pen.left(80)
pen.forward(80)
pen.end_fill()
pen.up()
pen.goto(0,0)
pen.goto(-150,-20)
pen.down()
#cửa sổ
pen.fillcolor("red")
pen.begin_fill()
pen.left(100)
pen.forward(20)
pen.left(80)
pen.forward(20)
pen.left(100)
pen.forward(20)
pen.left(80)
pen.forward(20)
pen.end_fill()
pen.penup()
pen.goto(-260,-80)
pen.down()
#cửa
pen.fillcolor("black")
pen.begin_fill()
pen.right(a)
pen.forward(30)
pen.right(a)
pen.forward(70)
pen.right(a)
pen.forward(30)
pen.right(a)
pen.forward(70)
pen.right(a)
pen.forward(30)
pen.end_fill()
#cây
pen.penup()
pen.goto(0,0)
pen.goto(200,-200)
pen.pendown()
pen.fillcolor("brown")
pen.begin_fill()
pen.right(a)
pen.forward(80)
pen.right(a)
pen.forward(50)
pen.right(a)
pen.forward(80)
pen.right(a)
pen.forward(50)
pen.end_fill()
pen.penup()
pen.right(a)
pen.forward(80)
pen.right(a)
pen.forward(25)
pen.pendown()
pen.fillcolor("green")
pen.begin_fill()
pen.forward(75)
pen.left(120)
pen.forward(150)
pen.left(120)
pen.forward(150)
pen.left(120)
pen.forward(150)
pen.left(120)
pen.forward(150)
pen.end_fill()
pen.fillcolor("green")
pen.begin_fill()
pen.left(60)
pen.forward(50)
pen.right(120)
pen.forward(100)
pen.right(120)
pen.forward(100)
pen.right(120)
pen.forward(100)
pen.right(120)
pen.forward(100)
pen.end_fill()
pen.fillcolor("green")
pen.begin_fill()
pen.right(60)
pen.forward(25)
pen.left(120)
pen.forward(50)
pen.left(120)
pen.forward(50)
pen.left(120)
pen.forward(50)
pen.end_fill()
pen.penup()
pen.goto(50,100)
pen.pendown()
pen.fillcolor("orange")
pen.begin_fill()
pen.circle(100)
pen.end_fill()
turtle.done()
# Out:
# ---------------------------------------------------------------------------
# Terminator                                Traceback (most recent call last)
# Cell In[2], line 2
#       1 import turtle
# ----> 2 pen = turtle.Turtle()
#       3 a=90
#       4 turtle.bgcolor("cyan")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\turtle.py:3831, in Turtle.__init__(self, shape, undobuffersize, visible)
#    3829 if Turtle._screen is None:
#    3830     Turtle._screen = Screen()
# -> 3831 RawTurtle.__init__(self, Turtle._screen,
#    3832                    shape=shape,
#    3833                    undobuffersize=undobuffersize,
#    3834                    visible=visible)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\turtle.py:2558, in RawTurtle.__init__(self, canvas, shape, undobuffersize, visible)
#    2556 self._undobuffersize = undobuffersize
#    2557 self.undobuffer = Tbuffer(undobuffersize)
# -> 2558 self._update()
#
# ...
