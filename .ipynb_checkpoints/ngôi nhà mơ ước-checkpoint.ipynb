# %%
import turtle
pen = turtle.Turtle()
turtle.bgcolor("cyan")
pen.speed(5)
pen.penup()
pen.backward(300)
pen.pendown()
pen.fillcolor("yellow")
pen.begin_fill()
pen.forward(50)
pen.right(90)
pen.forward(80)
pen.right(90)
pen.forward(50)
pen.right(90)
pen.forward(80)
pen.end_fill()
#mặt 2
pen.fillcolor("brown")
pen.begin_fill()
pen.right(30)
pen.forward(50)
pen.right(120)
pen.forward(50)
pen.right(120)
pen.forward(50)
pen.right(120)
pen.forward(50)
pen.right(120)
pen.forward(50)
pen.left(70)
pen.forward(150)
pen.left(110)
pen.forward(50)
pen.left(70)
pen.forward(150)
pen.end_fill()
#mặt 2.5
pen.penup()
pen.left(50)
pen.forward(50)
pen.left(30)
pen.forward(80)
pen.left(90)
pen.forward(50)
pen.pendown()
pen.fillcolor("yellow")
pen.begin_fill()
pen.left(10)
pen.forward(150)
pen.left(80)
pen.forward(80)
pen.left(100)
pen.forward(150)
pen.left(80)
pen.forward(80)
pen.end_fill()
pen.up()
pen.goto(0,0)
pen.goto(-150,-20)
pen.down()
#cửa sổ
pen.fillcolor("red")
pen.begin_fill()
pen.left(100)
pen.forward(20)
pen.left(80)
pen.forward(20)
pen.left(100)
pen.forward(20)
pen.left(80)
pen.forward(20)
pen.end_fill()
pen.penup()
pen.goto(-260,-80)
pen.down()
#cửa
pen.fillcolor("black")
pen.begin_fill()
pen.right(90)
pen.forward(30)
pen.right(90)
pen.forward(70)
pen.right(90)
pen.forward(30)
pen.right(90)
pen.forward(70)
pen.right(90)
pen.forward(30)
pen.end_fill()
#cây
pen.penup()
pen.goto(0,0)
pen.goto(200,-200)
pen.pendown()
pen.fillcolor("brown")
pen.begin_fill()
pen.right(90)
pen.forward(80)
pen.right(90)
pen.forward(50)
pen.right(90)
pen.forward(80)
pen.right(90)
pen.forward(50)
pen.end_fill()
pen.penup()
pen.right(90)
pen.forward(80)
pen.right(90)
pen.forward(25)
pen.pendown()
pen.fillcolor("green")
pen.begin_fill()
pen.forward(75)
pen.left(120)
pen.forward(150)
pen.left(120)
pen.forward(150)
pen.left(120)
pen.forward(150)
pen.left(120)
pen.forward(150)
pen.end_fill()
pen.fillcolor("green")
pen.begin_fill()
pen.left(60)
pen.forward(50)
pen.right(120)
pen.forward(100)
pen.right(120)
pen.forward(100)
pen.right(120)
pen.forward(100)
pen.right(120)
pen.forward(100)
pen.end_fill()
pen.fillcolor("green")
pen.begin_fill()
pen.right(60)
pen.forward(25)
pen.left(120)
pen.forward(50)
pen.left(120)
pen.forward(50)
pen.left(120)
pen.forward(50)
pen.end_fill()
pen.penup()
pen.goto(50,100)
pen.pendown()
pen.fillcolor("orange")
pen.begin_fill()
pen.circle(100)
pen.end_fill()
turtle.done()
